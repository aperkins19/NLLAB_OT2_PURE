# %%
#import macroparameters

import pandas as pd
import numpy as np
import math
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

import plotly.express as px

    
import os, sys, shutil


def print_all_df(df):
    # Permanently changes the pandas settings
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', None)
    pd.set_option('display.max_colwidth', -1)
    
    # All dataframes hereafter reflect these changes.
    display(df)
    
    print('**RESET_OPTIONS**')
    
    # Resets the options
    pd.reset_option('all')

# %% [markdown]
# # Define Prefix of which experiment to analyse

# %%
prefix = "ALTE007"

experiment_file_path = "/app/src/OT2_scripts/" + prefix

data_path = experiment_file_path + "/processed_data_files/"

plots_path = experiment_file_path + "/plots/"

# %%
# navigate into tidy_data_files and make a list of all files

os.chdir(data_path)

items = os.listdir(".")

# lists all .csv
csv_list = []
for names in items:
    if names.endswith(".csv"):
        csv_list.append(names)
print(csv_list)
# Out:
# ['ALTE007_parsed_dataset.csv', 'ALTE007_tidy_data.csv']

# %%
# import the correct tidy dataset

print(os.getcwd())

# make file name
dataset = prefix +'_tidy_data.csv'

# import into pandas DF
all_gain_data = pd.read_csv(dataset, header=0)

# change back to /src for neatness
os.chdir('/app')
# Out:
# /app/src/OT2_scripts/ALTE007/processed_data_files

# %%
# get the individual experiment numbers
experiment_numbers = all_gain_data['Experiment #'].unique()
experiment_numbers
# Out:
# array([ 9, 10])

# %%
# get the individual products
product_list = all_gain_data['Expression Product'].unique()
product_list
# Out:
# array(['GFP'], dtype=object)

# %% [markdown]
# # Plot all replicates for both gain settings

# %%
fig = plt.figure(figsize=(15,10))

plot_counter = 1

for i, exp_num in enumerate(experiment_numbers):
    
    #just get the individual experiment
    experiment_subsection = all_gain_data[all_gain_data['Experiment #'] == exp_num]


    for i, product in enumerate(product_list):

        #just get the individual product
        product_subsection = experiment_subsection[experiment_subsection['Expression Product'] == product]

        # get individual gain values of product subsection
        gain_list = product_subsection['Gain Setting'].unique()

        for i, gain in enumerate(gain_list):



            #just get the individual gain of the product slice

            gain_subsection = product_subsection[product_subsection['Gain Setting'] == gain]


            # get individual gain

            ax = plt.subplot(2, 2, plot_counter)

            sns.lineplot(data = gain_subsection,
                    x = 'Time (Minutes)',
                    y = 'RFUs',
                    hue = 'Replicate',
                    legend='full',
                    ax=ax)

            ax.legend(title="Replicate #", loc = 2, bbox_to_anchor = (1,1))
            ax.set(title="Exp #:" +str(exp_num) + ", Gain Setting: " + str(gain_subsection['Gain Setting'].unique()))

            plot_counter += 1


#fig.text(0.001, 0.65, 'Malachite Green', ha='center', rotation="vertical")
#fig.text(0.001, 0.25, 'GFP', ha='center', rotation="vertical")


fig.suptitle(prefix+ " All Replicates")
fig.tight_layout()




##### Save fig


path = plots_path

# make directory for sticking the output in
if os.path.isdir(path) == False:
    os.mkdir(path, mode=0o777)
    
    
#navigate to tidy_data_files
os.chdir(path)

plt.savefig(prefix+"_plate_reader_run_all_replicates.png")


#navigate home for neatness
os.chdir('/app')



plt.show()

# %%
fig = plt.figure(figsize=(15,10))

plot_counter = 1

for i, exp_num in enumerate(experiment_numbers):
    
    #just get the individual experiment
    experiment_subsection = all_gain_data[all_gain_data['Experiment #'] == exp_num]


    for i, product in enumerate(product_list):

        #just get the individual product
        product_subsection = experiment_subsection[experiment_subsection['Expression Product'] == product]

        # get individual gain values of product subsection
        gain_list = product_subsection['Gain Setting'].unique()

        for i, gain in enumerate(gain_list):



            #just get the individual gain of the product slice

            gain_subsection = product_subsection[product_subsection['Gain Setting'] == gain]


            # get individual gain

            ax = plt.subplot(2, 2, plot_counter)

            sns.lineplot(data = gain_subsection,
                    x = 'Time (Minutes)',
                    y = 'RFUs',
                    ci = 'sd',
                    legend='full',
                    ax=ax)

            ax.set(title="Exp #:" +str(exp_num) + ", Gain Setting: " + str(gain_subsection['Gain Setting'].unique()))
            plot_counter += 1

fig.text(0.001, 0.65, 'Malachite Green', ha='center', rotation="vertical")
fig.text(0.001, 0.25, 'GFP', ha='center', rotation="vertical")

fig.suptitle(prefix+ " Mean & SD")
fig.tight_layout()



##### Save fig


path = plots_path

# make directory for sticking the output in
if os.path.isdir(path) == False:
    os.mkdir(path, mode=0o777)
    
    
#navigate to tidy_data_files
os.chdir(path)

plt.savefig(prefix+"_plate_reader_run_mean_sd.png")


#navigate home for neatness
os.chdir('/app')

plt.show()

# %%
GFP = all_gain_data[all_gain_data["Expression Product"] == "GFP"]
all_gain_data

timepoint = GFP[GFP["Time (Minutes)"] == 300]

timepoint = timepoint[timepoint['Gain Setting'] == 800]
timepoint
# Out:
#       Well   Sample ID  Time (Minutes)  RFUs  Gain Setting Chromatic Settings  \
# 10200  B03   Sample X1             300   417           800          485_520_1
# 10201  B05   Sample X2             300   446           800          485_520_1
# 10202  B07   Sample X3             300   488           800          485_520_1
# 10203  B09   Sample X4             300   428           800          485_520_1
# 10204  B11   Sample X5             300   482           800          485_520_1
# 10205  B13   Sample X6             300   537           800          485_520_1
# 10206  B15   Sample X7             300   385           800          485_520_1
# 10207  B17   Sample X8             300   414           800          485_520_1
# 10208  B19   Sample X9             300   351           800          485_520_1
# 10209  B21  Sample X10             300   241           800          485_520_1
# 10210  D03  Sample X11             300   378           800          485_520_1
# 10211  D05  Sample X12             300   369           800          485_520_1
# 10212  D07  Sample X13             300   445           800          485_520_1
# 10213  D09  Sample X14             300   453           800          485_520_1
# 10214  D11  Sample X15             300   465           800          485_520_1
# 10215  D13  Sample X16             300   569           800          485_520_1
# 10216  D15  Sample X17             300   502           800          485_520_1
# 10217  D17  Sample X18             300   473           800          485_520_1
# 10218  D19  Sample X19             300   356           800          485_520_1
# 10219  D21  Sample X20             300   304           800          485_520_1
#
#       Expression Product Amplicon DNA Template Energy Solution  Experiment #  \
# 10200                GFP         s70_deGFP_MGA       AP_ES_004             9
# 10201                GFP         s70_deGFP_MGA       AP_ES_004             9
# 10202                GFP         s70_deGFP_MGA       AP_ES_004             9
# 10203                GFP         s70_deGFP_MGA       AP_ES_004             9
# 10204                GFP         s70_deGFP_MGA       AP_ES_004             9
# 10205                GFP         s70_deGFP_MGA       AP_ES_004             9
# 10206                GFP         s70_deGFP_MGA       AP_ES_004             9
# 10207                GFP         s70_deGFP_MGA       AP_ES_004             9
# 10208                GFP         s70_deGFP_MGA       AP_ES_004             9
# 10209                GFP         s70_deGFP_MGA       AP_ES_004             9
# 10210                GFP         s70_deGFP_MGA  Michael_ES_001            10
# 10211                GFP         s70_deGFP_MGA  Michael_ES_001            10
# 10212                GFP         s70_deGFP_MGA  Michael_ES_001            10
# 10213                GFP         s70_deGFP_MGA  Michael_ES_001            10
# 10214                GFP         s70_deGFP_MGA  Michael_ES_001            10
# 10215                GFP         s70_deGFP_MGA  Michael_ES_001            10
# 10216                GFP         s70_deGFP_MGA  Michael_ES_001            10
# 10217                GFP         s70_deGFP_MGA  Michael_ES_001            10
# 10218                GFP         s70_deGFP_MGA  Michael_ES_001            10
# 10219                GFP         s70_deGFP_MGA  Michael_ES_001            10
#
#        ...  wax_dispense_height wax_dispense_volume  wax_disposal_volume  \
# 10200  ...                   -3                  35                   30
# 10201  ...                   -3                  35                   30
# 10202  ...                   -3                  35                   30
# 10203  ...                   -3                  35                   30
# 10204  ...                   -3                  35                   30
# 10205  ...                   -3                  35                   30
# 10206  ...                   -3                  35                   30
# 10207  ...                   -3                  35                   30
# 10208  ...                   -3                  35                   30
# 10209  ...                   -3                  35                   30
# 10210  ...                   -3                  35                   30
# 10211  ...                   -3                  35                   30
# 10212  ...                   -3                  35                   30
# 10213  ...                   -3                  35                   30
# 10214  ...                   -3                  35                   30
# 10215  ...                   -3                  35                   30
# 10216  ...                   -3                  35                   30
# 10217  ...                   -3                  35                   30
# 10218  ...                   -3                  35                   30
# 10219  ...                   -3                  35                   30
#
#       wax_new_tip  wax_touch_tip  Reaction Temperature (°C)  Performed by  \
# 10200       never          False                         37      AP & MJS
# 10201       never          False                         37      AP & MJS
# 10202       never          False                         37      AP & MJS
# 10203       never          False                         37      AP & MJS
# 10204       never          False                         37      AP & MJS
# 10205       never          False                         37      AP & MJS
# 10206       never          False                         37      AP & MJS
# 10207       never          False                         37      AP & MJS
# 10208       never          False                         37      AP & MJS
# 10209       never          False                         37      AP & MJS
# 10210       never          False                         37      AP & MJS
# 10211       never          False                         37      AP & MJS
# 10212       never          False                         37      AP & MJS
# 10213       never          False                         37      AP & MJS
# 10214       never          False                         37      AP & MJS
# 10215       never          False                         37      AP & MJS
# 10216       never          False                         37      AP & MJS
# 10217       never          False                         37      AP & MJS
# 10218       never          False                         37      AP & MJS
# 10219       never          False                         37      AP & MJS
#
#                 Instrument  Plate Reader Run #  Assay Date
# 10200  BMG POLARstar Omega                   6  2022-06-28
# 10201  BMG POLARstar Omega                   6  2022-06-28
# 10202  BMG POLARstar Omega                   6  2022-06-28
# 10203  BMG POLARstar Omega                   6  2022-06-28
# 10204  BMG POLARstar Omega                   6  2022-06-28
# 10205  BMG POLARstar Omega                   6  2022-06-28
# 10206  BMG POLARstar Omega                   6  2022-06-28
# 10207  BMG POLARstar Omega                   6  2022-06-28
# 10208  BMG POLARstar Omega                   6  2022-06-28
# 10209  BMG POLARstar Omega                   6  2022-06-28
# 10210  BMG POLARstar Omega                   6  2022-06-28
# 10211  BMG POLARstar Omega                   6  2022-06-28
# 10212  BMG POLARstar Omega                   6  2022-06-28
# 10213  BMG POLARstar Omega                   6  2022-06-28
# 10214  BMG POLARstar Omega                   6  2022-06-28
# 10215  BMG POLARstar Omega                   6  2022-06-28
# 10216  BMG POLARstar Omega                   6  2022-06-28
# 10217  BMG POLARstar Omega                   6  2022-06-28
# 10218  BMG POLARstar Omega                   6  2022-06-28
# 10219  BMG POLARstar Omega                   6  2022-06-28
#
# [20 rows x 29 columns]

# %%
fig = plt.figure(figsize=(10,5))

ax1 = sns.catplot(
            data = timepoint,
            x = "Experiment #",
            y = "RFUs",
            hue="Replicate",
            ax=ax,
            height=5,
            aspect=.8)

ax1 = sns.boxplot(
            data=timepoint,
            x="Experiment #",
            y="RFUs",
            ax=ax,
            whis=np.inf)


fig.suptitle("Plate_reader_run_"+prefix+ " Scatter Plot")
fig.tight_layout()


##### Save fig


path = plots_path

# make directory for sticking the output in
if os.path.isdir(path) == False:
    os.mkdir(path, mode=0o777)
    
    
#navigate to tidy_data_files
os.chdir(path)

plt.savefig(prefix+"_plate_reader_run_vertical_scatter_plot.png")


#navigate home for neatness
os.chdir('/app')

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try stripplot
#   warnings.warn(msg, UserWarning)

# %%
fig = plt.figure(figsize=(5,5))

ax = sns.boxplot(x="Experiment #", y="RFUs", data=timepoint, whis=np.inf, width=0.3)
ax = sns.stripplot(x="Experiment #", y="RFUs", data=timepoint, color=".3")

fig.suptitle(prefix+ " Strip Plot")
fig.tight_layout()


##### Save fig


path = plots_path

# make directory for sticking the output in
if os.path.isdir(path) == False:
    os.mkdir(path, mode=0o777)
    
    
#navigate to tidy_data_files
os.chdir(path)

plt.savefig(prefix+"_plate_reader_run_box_strip_plot.png.png")


#navigate home for neatness
os.chdir('/app')

plt.show()
