# %% [markdown]
# # Intro
#
# This script compiles the individual tidy_data.csv files in `/app/data/tidy_data_files` into a master csv.
# It also generates some summary plots:
#
# * Timeseries plots of individual experiments.
# * A series of box plots to represent the variance of the expression at a certain timepoint to be decided.
#
# It then saves a new tidy master csv: containing all of the timepoints for all experiments: `master_tidy_dataset.csv`

# %% [markdown]
# ## Import some stuff

# %%
#import macroparameters

import pandas as pd
import numpy as np
import math
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

import plotly.express as px

    
import os, sys, shutil


def print_all_df(df):
    # Permanently changes the pandas settings
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', None)
    pd.set_option('display.max_colwidth', -1)
    
    # All dataframes hereafter reflect these changes.
    display(df)
    
    print('**RESET_OPTIONS**')
    
    # Resets the options
    pd.reset_option('all')

# %% [markdown]
# # List all the tidy data .csvs in the directory

# %%
# navigate into tidy_data_files and make a list of all files

os.chdir('/app/data/tidy_data_files')
os.getcwd()

items = os.listdir(".")

# lists all .csv
csv_list = []
for names in items:
    if names.endswith(".csv"):
        csv_list.append(names)
print(csv_list)
# Out:
# ['ALTE001_tidy_data.csv', 'ALTE002_tidy_data.csv', 'ALTE003_tidy_data.csv', 'ALTE004_tidy_data.csv']

# %% [markdown]
# First we need to store the max time for each experiment in a list. The experiments vary so this needs to be done dynamically.

# %% [markdown]
# # Preliminary time course plotting
#
# First concatentate all dfs and save as `master_tidy_dataset.csv`

# %%
all_times = pd.DataFrame()
os.chdir('/app/data/tidy_data_files')

# First combine all dfs
for csv in csv_list:
    
    #import into df
    experiment_tidy_data = pd.read_csv(csv, header=0)
    
    # add the series to the stats df as a row
    all_times = all_times.append(experiment_tidy_data)


    ### save
path = "/app/data/"

# make directory for sticking the output in
if os.path.isdir(path) == False:
    os.mkdir(path, mode=0o777)
    
    
#navigate to tidy_data_files
os.chdir(path)

all_times.to_csv("master_tidy_dataset.csv", index=False)


#navigate home for neatness
os.chdir('/app')
# Out:
# /tmp/ipykernel_951/2173851510.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_times = all_times.append(experiment_tidy_data)
# /tmp/ipykernel_951/2173851510.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_times = all_times.append(experiment_tidy_data)
# /tmp/ipykernel_951/2173851510.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_times = all_times.append(experiment_tidy_data)
# /tmp/ipykernel_951/2173851510.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_times = all_times.append(experiment_tidy_data)

# %% [markdown]
# # Now trim the df a bit to only get the same chromatic

# %%
all_times = all_times[all_times['Expression Product']=="GFP"]
all_times = all_times[all_times['Gain Setting']==800]
all_times = all_times.reset_index(drop=True)

# %% [markdown]
# # Plot individual replicates for each experiments

# %%
fig = plt.figure(figsize=(15,10))

# Calculate the appropriate amount of subplots and their layout

# Get the total number of experiments
total_experiments = all_times['Experiment #'].unique().max()

if total_experiments%2 == 0:
    subplot_rows = 2
    subplot_cols = int(total_experiments/2)



for exp in all_times['Experiment #'].unique():
    print(exp)
    
    exp_df = all_times[all_times['Experiment #'] == exp]
    
    ax = plt.subplot(subplot_rows, subplot_cols, exp)
    
    sns.lineplot(data = exp_df,
                 x = "Time (Minutes)",
                 y = "RFUs",
                 hue = "Replicate",
                 ax= ax,
                ci=None)
    
    ax.set_title("Experiment #: "+str(exp))
    ax.legend(title="Replicate #", loc = 2, bbox_to_anchor = (1,1))



fig.suptitle("RFUs of all Replicates over time in each experiment")
fig.tight_layout()


##### Save fig


path = "/app/data/plots/"

# make directory for sticking the output in
if os.path.isdir(path) == False:
    os.mkdir(path, mode=0o777)
    
    
#navigate to tidy_data_files
os.chdir(path)

plt.savefig("all_timeseries_rfus.png")


#navigate home for neatness
os.chdir('/app')

plt.show()
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# # Define the time point to use as an endpoint
#
# Now we have all off the max times, we'll simply set the smallest as the timepoint that we'll use as the endpoint reading this may change.

# %%
### initalise df using the columns
os.chdir('/app/data/tidy_data_files')

# iterate over the datasets and store the max time in a list
max_times = []
for csv in csv_list:
    
    #import into df
    experiment_tidy_data = pd.read_csv(csv, header=0)
    max_times.append(experiment_tidy_data['Time (Minutes)'].max())
    
timepoint = min(max_times)
print(timepoint)

#os.chdir('/app')
# Out:
# 184

# %% [markdown]
# Now we'll slice the individual dataframes to keep only the gain setting we want and the readings at the timepoint identified above. We'll produce a df called stats

# %%
### initalise df using the columns
os.chdir('/app/data/tidy_data_files')


# id columns
cols = pd.read_csv(csv_list[0], header=0)
cols = cols.drop(["Sample ID", "Well", "Chromatic Settings"], axis='columns')
cols = cols.columns


stats = pd.DataFrame(columns=cols)

# iterate over the datasets
for csv in csv_list:
    
    #import into df
    experiment_tidy_data = pd.read_csv(csv, header=0)
    
    # use the time point to slice the dataframe
    timepoint_slice = experiment_tidy_data[experiment_tidy_data['Time (Minutes)'] == timepoint].copy()
    
    # now just save the right gainsetting
    gain_setting_slice = timepoint_slice[timepoint_slice['Gain Setting'] == 800].copy()
    # now just save the right gainsetting
    gain_setting_slice = gain_setting_slice[gain_setting_slice['Expression Product'] == "GFP"].copy()
    
    # generate stats
    gain_setting_slice['Mean'] = gain_setting_slice['RFUs'].mean()
    gain_setting_slice['SEM'] = gain_setting_slice['RFUs'].sem()
    
    # Drop the stuff we don't need.
    gain_setting_slice = gain_setting_slice.reset_index(drop=True)
    gain_setting_slice = gain_setting_slice.drop([ "Sample ID", "Well", "Chromatic Settings"], axis='columns')
    
    # add the series to the stats df as a row
    stats = stats.append(gain_setting_slice)



stats = stats.reset_index(drop=True)
print_all_df(stats)
# Out:
# /tmp/ipykernel_951/952541412.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stats = stats.append(gain_setting_slice)
# /tmp/ipykernel_951/952541412.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stats = stats.append(gain_setting_slice)
# /tmp/ipykernel_951/952541412.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stats = stats.append(gain_setting_slice)
# /tmp/ipykernel_951/952541412.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stats = stats.append(gain_setting_slice)
# /tmp/ipykernel_951/4012125076.py:21: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#    Time (Minutes)  RFUs Gain Setting Expression Product Amplicon DNA Template  \
# 0   184            75    800          GFP                s70_deGFP_MGA
# 1   184            76    800          GFP                s70_deGFP_MGA
# 2   184            76    800          GFP                s70_deGFP_MGA
# 3   184            78    800          GFP                s70_deGFP_MGA
# 4   184            79    800          GFP                s70_deGFP_MGA
# 5   184            81    800          GFP                s70_deGFP_MGA
# 6   184            80    800          GFP                s70_deGFP_MGA
# 7   184            78    800          GFP                s70_deGFP_MGA
# 8   184            82    800          GFP                s70_deGFP_MGA
# 9   184            78    800          GFP                s70_deGFP_MGA
# 10  184            76    800          GFP                s70_deGFP_MGA
# 11  184            95    800          GFP                s70_deGFP_MGA
# 12  184            93    800          GFP                s70_deGFP_MGA
# 13  184            93    800          GFP                s70_deGFP_MGA
# 14  184            71    800          GFP                s70_deGFP_MGA
# 15  184            99    800          GFP                s70_deGFP_MGA
# 16  184            91    800          GFP                s70_deGFP_MGA
# 17  184            73    800          GFP                s70_deGFP_MGA
# 18  184            93    800          GFP                s70_deGFP_MGA
# 19  184            99    800          GFP                s70_deGFP_MGA
# 20  184            96    800          GFP                s70_deGFP_MGA
# 21  184            180   800          GFP                s70_deGFP_MGA
# 22  184            225   800          GFP                s70_deGFP_MGA
# 23  184            92    800          GFP                s70_deGFP_MGA
# 24  184            255   800          GFP                s70_deGFP_MGA
# 25  184            251   800          GFP                s70_deGFP_MGA
# 26  184            138   800          GFP                s70_deGFP_MGA
# 27  184            325   800          GFP                s70_deGFP_MGA
# 28  184            1262  800          GFP                s70_deGFP_MGA
# 29  184            111   800          GFP                s70_deGFP_MGA
# 30  184            80    800          GFP                s70_deGFP_MGA
# 31  184            79    800          GFP                s70_deGFP_MGA
# 32  184            81    800          GFP                s70_deGFP_MGA
# 33  184            78    800          GFP                s70_deGFP_MGA
# 34  184            77    800          GFP                s70_deGFP_MGA
# 35  184            97    800          GFP                s70_deGFP_MGA
# 36  184            73    800          GFP                s70_deGFP_MGA
# 37  184            74    800          GFP                s70_deGFP_MGA
# 38  184            72    800          GFP                s70_deGFP_MGA
# 39  184            79    800          GFP                s70_deGFP_MGA
#
#    Energy Solution Reaction Type Replicate              System  \
# 0   Michael_ES_001  TXTL          1         Michael_Lysate_001
# 1   Michael_ES_001  TXTL          2         Michael_Lysate_001
# 2   Michael_ES_001  TXTL          3         Michael_Lysate_001
# 3   Michael_ES_001  TXTL          4         Michael_Lysate_001
# 4   Michael_ES_001  TXTL          5         Michael_Lysate_001
# 5   Michael_ES_001  TXTL          6         Michael_Lysate_001
# 6   Michael_ES_001  TXTL          7         Michael_Lysate_001
# 7   Michael_ES_001  TXTL          8         Michael_Lysate_001
# 8   Michael_ES_001  TXTL          9         Michael_Lysate_001
# 9   Michael_ES_001  TXTL          10        Michael_Lysate_001
# 10  Michael_ES_001  TXTL          1         Michael_Lysate_001
# 11  Michael_ES_001  TXTL          2         Michael_Lysate_001
# 12  Michael_ES_001  TXTL          3         Michael_Lysate_001
# 13  Michael_ES_001  TXTL          4         Michael_Lysate_001
# 14  Michael_ES_001  TXTL          5         Michael_Lysate_001
# 15  Michael_ES_001  TXTL          6         Michael_Lysate_001
# 16  Michael_ES_001  TXTL          7         Michael_Lysate_001
# 17  Michael_ES_001  TXTL          8         Michael_Lysate_001
# 18  Michael_ES_001  TXTL          9         Michael_Lysate_001
# 19  Michael_ES_001  TXTL          10        Michael_Lysate_001
# 20  AP_ES_003       TXTL          1         AP_Lysate_003
# 21  AP_ES_003       TXTL          2         AP_Lysate_003
# 22  AP_ES_003       TXTL          3         AP_Lysate_003
# 23  AP_ES_003       TXTL          4         AP_ES_003
# 24  AP_ES_003       TXTL          5         AP_Lysate_003
# 25  AP_ES_003       TXTL          6         AP_Lysate_003
# 26  AP_ES_003       TXTL          7         AP_Lysate_003
# 27  AP_ES_003       TXTL          8         AP_Lysate_003
# 28  AP_ES_003       TXTL          9         AP_Lysate_003
# 29  AP_ES_003       TXTL          10        AP_Lysate_003
# 30  Michael_ES_001  TXTL          1         Michael_Lysate_001
# 31  Michael_ES_001  TXTL          2         Michael_Lysate_001
# 32  Michael_ES_001  TXTL          3         Michael_Lysate_001
# 33  Michael_ES_001  TXTL          4         Michael_Lysate_001
# 34  Michael_ES_001  TXTL          5         Michael_Lysate_001
# 35  Michael_ES_001  TXTL          6         Michael_Lysate_001
# 36  Michael_ES_001  TXTL          7         Michael_Lysate_001
# 37  Michael_ES_001  TXTL          8         Michael_Lysate_001
# 38  Michael_ES_001  TXTL          9         Michael_Lysate_001
# 39  Michael_ES_001  TXTL          10        Michael_Lysate_001
#
#    Reaction Temperature (°C) Performed by           Instrument Experiment #  \
# 0   30                        AP & MJS     BMG POLARstar Omega  1
# 1   30                        AP & MJS     BMG POLARstar Omega  1
# 2   30                        AP & MJS     BMG POLARstar Omega  1
# 3   30                        AP & MJS     BMG POLARstar Omega  1
# 4   30                        AP & MJS     BMG POLARstar Omega  1
# 5   30                        AP & MJS     BMG POLARstar Omega  1
# 6   30                        AP & MJS     BMG POLARstar Omega  1
# 7   30                        AP & MJS     BMG POLARstar Omega  1
# 8   30                        AP & MJS     BMG POLARstar Omega  1
# 9   30                        AP & MJS     BMG POLARstar Omega  1
# 10  37                        AP & MJS     BMG POLARstar Omega  2
# 11  37                        AP & MJS     BMG POLARstar Omega  2
# 12  37                        AP & MJS     BMG POLARstar Omega  2
# 13  37                        AP & MJS     BMG POLARstar Omega  2
# 14  37                        AP & MJS     BMG POLARstar Omega  2
# 15  37                        AP & MJS     BMG POLARstar Omega  2
# 16  37                        AP & MJS     BMG POLARstar Omega  2
# 17  37                        AP & MJS     BMG POLARstar Omega  2
# 18  37                        AP & MJS     BMG POLARstar Omega  2
# 19  37                        AP & MJS     BMG POLARstar Omega  2
# 20  37                        AP & MJS     BMG POLARstar Omega  3
# 21  37                        AP & MJS     BMG POLARstar Omega  3
# 22  37                        AP & MJS     BMG POLARstar Omega  3
# 23  37                        AP & MJS     BMG POLARstar Omega  3
# 24  37                        AP & MJS     BMG POLARstar Omega  3
# 25  37                        AP & MJS     BMG POLARstar Omega  3
# 26  37                        AP & MJS     BMG POLARstar Omega  3
# 27  37                        AP & MJS     BMG POLARstar Omega  3
# 28  37                        AP & MJS     BMG POLARstar Omega  3
# 29  37                        AP & MJS     BMG POLARstar Omega  3
# 30  37                        AP & MJS     BMG POLARstar Omega  4
# 31  37                        AP & MJS     BMG POLARstar Omega  4
# 32  37                        AP & MJS     BMG POLARstar Omega  4
# 33  37                        AP & MJS     BMG POLARstar Omega  4
# 34  37                        AP & MJS     BMG POLARstar Omega  4
# 35  37                        AP & MJS     BMG POLARstar Omega  4
# 36  37                        AP & MJS     BMG POLARstar Omega  4
# 37  37                        AP & MJS     BMG POLARstar Omega  4
# 38  37                        AP & MJS     BMG POLARstar Omega  4
# 39  37                        AP & MJS     BMG POLARstar Omega  4
#
#    lysate_aspirate_height_init lysate_aspirate_height_inc  \
# 0   4.5                         0.4
# 1   4.5                         0.4
# 2   4.5                         0.4
# 3   4.5                         0.4
# 4   4.5                         0.4
# 5   4.5                         0.4
# 6   4.5                         0.4
# 7   4.5                         0.4
# 8   4.5                         0.4
# 9   4.5                         0.4
# 10  4.5                         0.4
# 11  4.5                         0.4
# 12  4.5                         0.4
# 13  4.5                         0.4
# 14  4.5                         0.4
# 15  4.5                         0.4
# 16  4.5                         0.4
# 17  4.5                         0.4
# 18  4.5                         0.4
# 19  4.5                         0.4
# 20  4.5                         0.4
# 21  4.5                         0.4
# 22  4.5                         0.4
# 23  4.5                         0.4
# 24  4.5                         0.4
# 25  4.5                         0.4
# 26  4.5                         0.4
# 27  4.5                         0.4
# 28  4.5                         0.4
# 29  4.5                         0.4
# 30  4.5                         0.4
# 31  4.5                         0.4
# 32  4.5                         0.4
# 33  4.5                         0.4
# 34  4.5                         0.4
# 35  4.5                         0.4
# 36  4.5                         0.4
# 37  4.5                         0.4
# 38  4.5                         0.4
# 39  4.5                         0.4
#
#    substrates_aspirate_height_init substrates_aspirate_height_inc  \
# 0   9                               0.4
# 1   9                               0.4
# 2   9                               0.4
# 3   9                               0.4
# 4   9                               0.4
# 5   9                               0.4
# 6   9                               0.4
# 7   9                               0.4
# 8   9                               0.4
# 9   9                               0.4
# 10  9                               0.4
# 11  9                               0.4
# 12  9                               0.4
# 13  9                               0.4
# 14  9                               0.4
# 15  9                               0.4
# 16  9                               0.4
# 17  9                               0.4
# 18  9                               0.4
# 19  9                               0.4
# 20  9                               0.4
# 21  9                               0.4
# 22  9                               0.4
# 23  9                               0.4
# 24  9                               0.4
# 25  9                               0.4
# 26  9                               0.4
# 27  9                               0.4
# 28  9                               0.4
# 29  9                               0.4
# 30  8.6                             0.4
# 31  8.6                             0.4
# 32  8.6                             0.4
# 33  8.6                             0.4
# 34  8.6                             0.4
# 35  8.6                             0.4
# 36  8.6                             0.4
# 37  8.6                             0.4
# 38  8.6                             0.4
# 39  8.6                             0.4
#
#    wax_dispense_volume wax_dispense_height wax_new_tip wax_touch_tip  \
# 0   35                  5                   never       True
# 1   35                  5                   never       True
# 2   35                  5                   never       True
# 3   35                  5                   never       True
# 4   35                  5                   never       True
# 5   35                  5                   never       True
# 6   35                  5                   never       True
# 7   35                  5                   never       True
# 8   35                  5                   never       True
# 9   35                  5                   never       True
# 10  35                  -3                  never       False
# 11  35                  -3                  never       False
# 12  35                  -3                  never       False
# 13  35                  -3                  never       False
# 14  35                  -3                  never       False
# 15  35                  -3                  never       False
# 16  35                  -3                  never       False
# 17  35                  -3                  never       False
# 18  35                  -3                  never       False
# 19  35                  -3                  never       False
# 20  35                  -3                  never       False
# 21  35                  -3                  never       False
# 22  35                  -3                  never       False
# 23  35                  -3                  never       False
# 24  35                  -3                  never       False
# 25  35                  -3                  never       False
# 26  35                  -3                  never       False
# 27  35                  -3                  never       False
# 28  35                  -3                  never       False
# 29  35                  -3                  never       False
# 30  35                  -3                  never       False
# 31  35                  -3                  never       False
# 32  35                  -3                  never       False
# 33  35                  -3                  never       False
# 34  35                  -3                  never       False
# 35  35                  -3                  never       False
# 36  35                  -3                  never       False
# 37  35                  -3                  never       False
# 38  35                  -3                  never       False
# 39  35                  -3                  never       False
#
#    wax_air_gap wax_disposal_volume  Assay Date   Mean         SEM
# 0   20          30                  2022-01-06  78.3   0.715697
# 1   20          30                  2022-01-06  78.3   0.715697
# 2   20          30                  2022-01-06  78.3   0.715697
# 3   20          30                  2022-01-06  78.3   0.715697
# 4   20          30                  2022-01-06  78.3   0.715697
# 5   20          30                  2022-01-06  78.3   0.715697
# 6   20          30                  2022-01-06  78.3   0.715697
# 7   20          30                  2022-01-06  78.3   0.715697
# 8   20          30                  2022-01-06  78.3   0.715697
# 9   20          30                  2022-01-06  78.3   0.715697
# 10  20          30                  2022-02-06  88.3   3.386411
# 11  20          30                  2022-02-06  88.3   3.386411
# 12  20          30                  2022-02-06  88.3   3.386411
# 13  20          30                  2022-02-06  88.3   3.386411
# 14  20          30                  2022-02-06  88.3   3.386411
# 15  20          30                  2022-02-06  88.3   3.386411
# 16  20          30                  2022-02-06  88.3   3.386411
# 17  20          30                  2022-02-06  88.3   3.386411
# 18  20          30                  2022-02-06  88.3   3.386411
# 19  20          30                  2022-02-06  88.3   3.386411
# 20  20          30                  2022-02-06  293.5  110.400408
# 21  20          30                  2022-02-06  293.5  110.400408
# 22  20          30                  2022-02-06  293.5  110.400408
# 23  20          30                  2022-02-06  293.5  110.400408
# 24  20          30                  2022-02-06  293.5  110.400408
# 25  20          30                  2022-02-06  293.5  110.400408
# 26  20          30                  2022-02-06  293.5  110.400408
# 27  20          30                  2022-02-06  293.5  110.400408
# 28  20          30                  2022-02-06  293.5  110.400408
# 29  20          30                  2022-02-06  293.5  110.400408
# 30  20          30                  2022-07-06  79.0   2.221111
# 31  20          30                  2022-07-06  79.0   2.221111
# 32  20          30                  2022-07-06  79.0   2.221111
# 33  20          30                  2022-07-06  79.0   2.221111
# 34  20          30                  2022-07-06  79.0   2.221111
# 35  20          30                  2022-07-06  79.0   2.221111
# 36  20          30                  2022-07-06  79.0   2.221111
# 37  20          30                  2022-07-06  79.0   2.221111
# 38  20          30                  2022-07-06  79.0   2.221111
# 39  20          30                  2022-07-06  79.0   2.221111
# **RESET_OPTIONS**
# /usr/local/lib/python3.10/dist-packages/pandas/_config/config.py:653: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead.
#   warnings.warn(d.msg, FutureWarning)
# /usr/local/lib/python3.10/dist-packages/pandas/_config/config.py:653: FutureWarning:
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
#
#   warnings.warn(d.msg, FutureWarning)

# %% [markdown]
# # Box plot of each experiment

# %%
fig = plt.figure(figsize=(10,5))

ax = sns.boxplot(x="Experiment #", y="RFUs", data=stats, whis=np.inf, width=0.3)
ax = sns.stripplot(x="Experiment #", y="RFUs", data=stats, color=".3")

ax.set_ylim(0,300)

fig.suptitle("RFUs of all experiments at "+ str(timepoint) + " mins")
fig.tight_layout()


##### Save fig


path = "/app/data/plots/"

# make directory for sticking the output in
if os.path.isdir(path) == False:
    os.mkdir(path, mode=0o777)
    
    
#navigate to tidy_data_files
os.chdir(path)

plt.savefig("experiment_rounds_box_plots.png")


#navigate home for neatness
os.chdir('/app')

plt.show()
